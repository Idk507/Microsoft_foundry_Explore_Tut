# %%
# %pip install azure-ai-projects==2.0.0b2 openai==1.109.1 python-dotenv azure-identity
# Out:
# Requirement already satisfied: azure-ai-projects==2.0.0b2 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (2.0.0b2)
# Requirement already satisfied: openai==1.109.1 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (1.109.1)
# Requirement already satisfied: python-dotenv in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (1.1.1)
# Requirement already satisfied: azure-identity in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (1.25.1)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from azure-ai-projects==2.0.0b2) (0.7.2)
# Requirement already satisfied: azure-core>=1.35.0 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from azure-ai-projects==2.0.0b2) (1.36.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from azure-ai-projects==2.0.0b2) (4.15.0)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from azure-ai-projects==2.0.0b2) (12.27.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from openai==1.109.1) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from openai==1.109.1) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from openai==1.109.1) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from openai==1.109.1) (0.11.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from openai==1.109.1) (2.11.4)
# Requirement already satisfied: sniffio in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from openai==1.109.1) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\dhanu\appdata\roaming\python\python311\site-packages (from openai==1.109.1) (4.67.1)
# Requirement already satisfied: idna>=2.8 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from anyio<5,>=3.5.0->openai==1.109.1) (3.10)
# Requirement already satisfied: certifi in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from httpx<1,>=0.23.0->openai==1.109.1) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from httpx<1,>=0.23.0->openai==1.109.1) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.109.1) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from pydantic<3,>=1.9.0->openai==1.109.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from pydantic<3,>=1.9.0->openai==1.109.1) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from pydantic<3,>=1.9.0->openai==1.109.1) (0.4.1)
# Requirement already satisfied: cryptography>=2.5 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from azure-identity) (45.0.7)
# Requirement already satisfied: msal>=1.30.0 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from azure-identity) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: requests>=2.21.0 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (2.32.5)
# Requirement already satisfied: cffi>=1.14 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from cryptography>=2.5->azure-identity) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from cffi>=1.14->cryptography>=2.5->azure-identity) (2.23)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.10.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dhanu\miniconda3\envs\idk\lib\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (2.6.3)
# Requirement already satisfied: colorama in c:\users\dhanu\appdata\roaming\python\python311\site-packages (from tqdm>4->openai==1.109.1) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient
load_dotenv()

foundry_project_endpoint = os.getenv("FOUNDRY_PROJECT_ENDPOINT")
model_deployment_name = os.getenv("MODEL_DEPLOYMENT_NAME")

# %%
project_client = AIProjectClient(
    endpoint=foundry_project_endpoint,
    credential=DefaultAzureCredential()
)

# %%
openai_client = project_client.get_openai_client()

# %%
response = openai_client.responses.create(
    model=model_deployment_name,
    instructions="You are a helpful AI assistant.",
    input = "Can you tell me about Microsoft Foundry?"
)

print(f"Response output: {response.output_text}")
